# %%
# test 0
class Book:
  def __init__(self,title,author,genre):
    self.__title=title
    self.__author=author
    self.__genre=genre
    self.__available = True
    self.__borrower = None

  def set_title(self,title):
    self.__title=title
  def get_title(self):
    return self.__title

  def get_author(self,author):
    self.__author=author
  def set_author(self):
    return self.__author

  def set_genre(self,genre):
    self.__genre=genre
  def get_genre(self):
    return self.__genre

  def set_availability(self,available):
    self.__available=available
  def get_availability(self):
    return self.__available

  def set_borrower(self,borrower):
    self.__borrower=borrower
  def get_borrower(self):
    return self.__borrower

  def display_info(self):
    print(f"Title: {self.__title}")
    print(f"Author: {self.__author}")
    print(f"Genre: {self.__genre}")
    print(f"Available: {self.__available}")
    print(f"Borrowed by: {self.__borrower}")
    print("---------------")

class LibraryMember:
  def __init__(self,id,name):
    self.__member_id=id
    self.__name=name
    self.__borrowed_books=[]

  def set_member_id(self,id):
    self.__member_id=id
  def get_member_id(self):
    return self.__member_id

  def set_name(self,name):
    self.__name=name
  def get_name(self):
    return self.__name

  def borrow_book(self,book):
    self.__borrowed_books.append(book)
    set_availability(False)
    self.set_borrower(self.__member_id)# member id naki name?
  def return_book(self,book):
    self.__borrowed_books.remove(book)
    set_borrower(None)
    set_availability(True)
  def display_borrowed_books(self):
    print(f"Books borrowed by {self.__name}")
    for i self.__borrowed_books:
      print(f"Title: {i.get_title()}\nAuthor: {i.get_author()}\nGenre: {i.get_genre()}\nAvailable: {i.get_availability()}")
    print("---------------")

class Library:
  def __init__(self):
    self.__books_available = []
    self.__library_members = []

  def add_book(self,book):
    self.__books_available.append(books)

  def add_library_member(self,member):
    self.__library_members.append(member)

  def display_book_list(self):
    print("All the books in the library are:")
    for i in self.__books_available:
      print(i.display_info())

  def display_library_member(self):
    for i in self.__library_members:
      print(f"Member Name: {i.get_name()}\nMember ID: {i.get_member_id()}")

# %%
# Test *-*
class Book:
  def __init__(self,title,author,genre):
    self.__title=title
    self.__author=author
    self.__genre=genre
    self.__available = True
    self.__borrower = None

  def set_title(self,title):
    self.__title=title
  def get_title(self):
    return self.__title

  def set_author(self,author):
    self.__author=author
  def get_author(self):
    return self.__author

  def set_genre(self,genre):
    self.__genre=genre
  def get_genre(self):
    return self.__genre

  def set_availability(self,available):
    self.__available=available
  def get_availability(self):
    return self.__available

  def set_borrower(self,borrower):
    self.__borrower=borrower
  def get_borrower(self):
    return self.__borrower

  def display_info(self):
    return(f"Title: {self.__title}\nAuthor: {self.__author}\nGenre: {self.__genre}\nAvailable: {self.__available}\nBorrowed by: {self.__borrower}\n---------------")

class LibraryMember:
  def __init__(self,id,name):
    self.__member_id=id
    self.__name=name
    self.__borrowed_books=[]

  def set_member_id(self,id):
    self.__member_id=id
  def get_member_id(self):
    return self.__member_id

  def set_name(self,name):
    self.__name=name
  def get_name(self):
    return self.__name

  def borrow_book(self,book):
    self.__borrowed_books.append(book)
    book.set_availability(False)
    book.set_borrower(self.__member_id)# member id naki name?
  def return_book(self,book):
    self.__borrowed_books.remove(book)
    book.set_borrower(None)
    book.set_availability(True)
  def display_borrowed_books(self):
    print(f"Books borrowed by {self.__name}")
    if len(self.__borrowed_books)!=0:
      for i in self.__borrowed_books:
        print(f"Title: {i.get_title()}\nAuthor: {i.get_author()}\nGenre: {i.get_genre()}\nAvailable: {i.get_availability()}")
        print("---------------")
    else:
      print(f"This member has not borrowed any book yet")

class Library:
  def __init__(self):
    self.__books_available = []
    self.__library_members = []

  def add_book(self,book):
    self.__books_available.append(book)

  def add_library_member(self,member):
    self.__library_members.append(member)

  def display_book_list(self):
    print("All the books in the library are:")
    for i in self.__books_available:
      print(i.display_info())

  def display_library_member(self):
    for i in self.__library_members:
      print(f"Member Name: {i.get_name()}\nMember ID: {i.get_member_id()}\n---------------")

book1 = Book("Harry Potter and the Chamber of Secrets", "J.K. Rowling", "Fiction")
book2 = Book("Nothing Lasts Forever", "Sidney Sheldon", "Fiction")
book3 = Book("Calculus", "Gilbert Strang", "Education")

# Create LibraryMember objects
member1 = LibraryMember("LM01", "Tom Cruise")
member2 = LibraryMember("LM02", "Brad Pitt")

# Create Library object
library = Library()

# Add books to the library
library.add_book(book1)
library.add_book(book2)
library.add_book(book3)

# Add library members
library.add_library_member(member1)
library.add_library_member(member2)

# Library members borrow books
member1.borrow_book(book1)
member1.borrow_book(book2)
member2.borrow_book(book3)

# Display all books in the library
library.display_book_list()
print("1======================================")

# Display library members and their borrowed books
member1.display_borrowed_books()
print("2======================================")
member2.display_borrowed_books()
print("3======================================")
# Returning  book book3 by member 2
member2.return_book(book3)
member2.display_borrowed_books()
# Returning book2 by member 1
member1.return_book(book2)
print("4======================================")
# Borrowing book1 and book2 by member 2
member2.borrow_book(book1)
member2.borrow_book(book3)
# Display library member2's borrowed books
member2.display_borrowed_books()
print("5======================================")
# Display library member1's borrowed books
member1.display_borrowed_books()
# Display all books in the library
library.display_book_list()
# Display all the available library members
library.display_library_member()
# Creating Book4 Object
book4 = Book("Percy Jackson & the Olympians", "Rick Riordan", "Fantasy")
# Adding book to the library
library.add_book(book4)
# Display all books in the library
library.display_book_list()
# Create LibraryMember objects
member3 = LibraryMember("LM03", "Samin Awsaf")
# Borrowing book1 and book4 by member 3
member3.borrow_book(book1)
member3.borrow_book(book4)
# Display library member3's borrowed books
member3.display_borrowed_books()
print("6======================================")
# Display all books in the library
library.display_book_list()
# Out:
# All the books in the library are:
# Title: Harry Potter and the Chamber of Secrets
# Author: J.K. Rowling
# Genre: Fiction
# Available: False
# Borrowed by: LM01
# ---------------
# Title: Nothing Lasts Forever
# Author: Sidney Sheldon
# Genre: Fiction
# Available: False
# Borrowed by: LM01
# ---------------
# Title: Calculus
# Author: Gilbert Strang
# Genre: Education
# Available: False
# Borrowed by: LM02
# ---------------
# 1======================================
# Books borrowed by Tom Cruise
# Title: Harry Potter and the Chamber of Secrets
# Author: J.K. Rowling
# Genre: Fiction
# Available: False
# ---------------
# Title: Nothing Lasts Forever
# Author: Sidney Sheldon
# Genre: Fiction
# Available: False
# ---------------
# 2======================================
# Books borrowed by Brad Pitt
# Title: Calculus
# Author: Gilbert Strang
# Genre: Education
# Available: False
# ---------------
# 3======================================
# Books borrowed by Brad Pitt
# This member has not borrowed any book yet
# 4======================================
# Books borrowed by Brad Pitt
# Title: Harry Potter and the Chamber of Secrets
# Author: J.K. Rowling
# Genre: Fiction
# Available: False
# ---------------
# Title: Calculus
# Author: Gilbert Strang
# Genre: Education
# Available: False
# ---------------
# 5======================================
# Books borrowed by Tom Cruise
# Title: Harry Potter and the Chamber of Secrets
# Author: J.K. Rowling
# Genre: Fiction
# Available: False
# ---------------
# All the books in the library are:
# Title: Harry Potter and the Chamber of Secrets
# Author: J.K. Rowling
# Genre: Fiction
# Available: False
# Borrowed by: LM02
# ---------------
# Title: Nothing Lasts Forever
# Author: Sidney Sheldon
# Genre: Fiction
# Available: True
# Borrowed by: None
# ---------------
# Title: Calculus
# Author: Gilbert Strang
# Genre: Education
# Available: False
# Borrowed by: LM02
# ---------------
# Member Name: Tom Cruise
# Member ID: LM01
# ---------------
# Member Name: Brad Pitt
# Member ID: LM02
# ---------------
# All the books in the library are:
# Title: Harry Potter and the Chamber of Secrets
# Author: J.K. Rowling
# Genre: Fiction
# Available: False
# Borrowed by: LM02
# ---------------
# Title: Nothing Lasts Forever
# Author: Sidney Sheldon
# Genre: Fiction
# Available: True
# Borrowed by: None
# ---------------
# Title: Calculus
# Author: Gilbert Strang
# Genre: Education
# Available: False
# Borrowed by: LM02
# ---------------
# Title: Percy Jackson & the Olympians
# Author: Rick Riordan
# Genre: Fantasy
# Available: True
# Borrowed by: None
# ---------------
# Books borrowed by Samin Awsaf
# Title: Harry Potter and the Chamber of Secrets
# Author: J.K. Rowling
# Genre: Fiction
# Available: False
# ---------------
# Title: Percy Jackson & the Olympians
# Author: Rick Riordan
# Genre: Fantasy
# Available: False
# ---------------
# 6======================================
# All the books in the library are:
# Title: Harry Potter and the Chamber of Secrets
# Author: J.K. Rowling
# Genre: Fiction
# Available: False
# Borrowed by: LM03
# ---------------
# Title: Nothing Lasts Forever
# Author: Sidney Sheldon
# Genre: Fiction
# Available: True
# Borrowed by: None
# ---------------
# Title: Calculus
# Author: Gilbert Strang
# Genre: Education
# Available: False
# Borrowed by: LM02
# ---------------
# Title: Percy Jackson & the Olympians
# Author: Rick Riordan
# Genre: Fantasy
# Available: False
# Borrowed by: LM03
# ---------------
